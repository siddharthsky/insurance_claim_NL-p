# %%
import pandas as pd
import warnings
warnings.filterwarnings("ignore")
from wordcloud import WordCloud
import os
import matplotlib.pyplot as plt

# %%
df= pd.read_excel("Dataset_Public2.xlsx")

# %%
df
# Out:
#                                       Claim Description Coverage Code  \
# 0     THE IV WAS MAKING A LEFT TURN ON A GREEN ARROW...            AN
# 1     CLAIMANT ALLEGES SHE SUFFERED INJURIES IN AN E...            GB
# 2     IV PASSENGER SUSTAINED INJURIES, OV AND IV COL...            AB
# 3     CLAIMANT ALLEGES SHE WAS BURNED UNKNOWN DEGREE...            PA
# 4     THE IV WAS MERGING INTO A CONSTRUCTION ZONE WH...            AD
# ...                                                 ...           ...
# 1023                                  VEHICLES MERGING.            AD
# 1024  CLAIMANT DROVE OVER A POTHOLE CAUSING VEHICLE ...            GD
# 1025  THE IV WAS COMING ACROSS THE BRIDGE FROM KENTU...            AP
# 1026  RECORD ONLY-  AC LEAKING IN APT#910, NO PERSON...            GD
# 1027  CUSTOMER PULLED INTO THE PARKING LOT AROUND 8:...            GD
#
#                                 Accident Source
# 0                    Struck pedestrian, bicycle
# 1                            Elevator/Escalator
# 2                      Sideswipe or lane change
# 3                                  Food Product
# 4                        Struck vehicle in rear
# ...                                         ...
# 1023                   Sideswipe or lane change
# 1024                                    Pothole
# 1025                   Sideswipe or lane change
# 1026  Plumbing,Heating,AC,Discharge,Overflowing
# 1027                                       Cart
#
# [1028 rows x 3 columns]

# %%
def WCplot(cl):
    colData = df[cl]
    singletxt = ''
    for mem in colData:
        singletxt += str(mem)
    # Create a WordCloud object
    wordcloud = WordCloud(width=800, height=400, background_color='white').generate(singletxt)
    # Plot the word cloud
    plt.figure(figsize=(10, 5))
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.axis('off')
    plt.savefig('temp/WCplot.png')
    #plt.show()

# %%
first_col = df.columns[0]
WCplot(first_col)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16032\3905182492.py in <module>
#       1 first_col = df.columns[0]
# ----> 2 WCplot(first_col)
#       3
#
# ~\AppData\Local\Temp\ipykernel_16032\2206886540.py in WCplot(cl)
#      10     plt.imshow(wordcloud, interpolation='bilinear')
#      11     plt.axis('off')
# ---> 12     plt.savefig('static/ooks_read.png')
#      13     #plt.show()
#      14
#
# ~\AppData\Roaming\Python\Python39\site-packages\matplotlib\pyplot.py in savefig(*args, **kwargs)
#     940 def savefig(*args, **kwargs):
#     941     fig = gcf()
# --> 942     res = fig.savefig(*args, **kwargs)
#     943     fig.canvas.draw_idle()  # Need this if 'transparent=True', to reset colors.
#     944     return res
#
# ~\AppData\Roaming\Python\Python39\site-packages\matplotlib\figure.py in savefig(self, fname, transparent, **kwargs)
#    3270                         ax.patch._cm_set(facecolor='none', edgecolor='none'))
#    3271
# -> 3272             self.canvas.print_figure(fname, **kwargs)
#    3273
#    3274     def ginput(self, n=1, timeout=30, show_clicks=True,
#
# ~\AppData\Roaming\Python\Python39\site-packages\matplotlib\backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2336                 # force the figure dpi to 72), so we need to set it again here.
#    2337                 with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2338                     result = print_method(
#    2339                         filename,
#    2340                         facecolor=facecolor,
#
# ~\AppData\Roaming\Python\Python39\site-packages\matplotlib\backend_bases.py in <lambda>(*args, **kwargs)
#    2202                 "bbox_inches_restore"}
#    2203             skip = optional_kws - {*inspect.signature(meth).parameters}
# -> 2204             print_method = functools.wraps(meth)(lambda *args, **kwargs: meth(
#    2205                 *args, **{k: v for k, v in kwargs.items() if k not in skip}))
#    2206         else:  # Let third-parties do as they see fit.
#
# ~\AppData\Roaming\Python\Python39\site-packages\matplotlib\_api\deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     408                          else deprecation_addendum,
#     409                 **kwargs)
# --> 410         return func(*inner_args, **inner_kwargs)
#     411
#     412     DECORATORS[wrapper] = decorator
#
# ~\AppData\Roaming\Python\Python39\site-packages\matplotlib\backends\backend_agg.py in print_png(self, filename_or_obj, metadata, pil_kwargs, *args)
#     518             *metadata*, including the default 'Software' key.
#     519         """
# --> 520         self._print_pil(filename_or_obj, "png", pil_kwargs, metadata)
#     521
#     522     def print_to_buffer(self):
#
# ~\AppData\Roaming\Python\Python39\site-packages\matplotlib\backends\backend_agg.py in _print_pil(self, filename_or_obj, fmt, pil_kwargs, metadata)
#     465         """
#     466         FigureCanvasAgg.draw(self)
# --> 467         mpl.image.imsave(
#     468             filename_or_obj, self.buffer_rgba(), format=fmt, origin="upper",
#     469             dpi=self.figure.dpi, metadata=metadata, pil_kwargs=pil_kwargs)
#
# ~\AppData\Roaming\Python\Python39\site-packages\matplotlib\image.py in imsave(fname, arr, vmin, vmax, cmap, format, origin, dpi, metadata, pil_kwargs)
#    1654         pil_kwargs.setdefault("format", format)
#    1655         pil_kwargs.setdefault("dpi", (dpi, dpi))
# -> 1656         image.save(fname, **pil_kwargs)
#    1657
#    1658
#
# ~\AppData\Roaming\Python\Python39\site-packages\PIL\Image.py in save(self, fp, format, **params)
#    2348                 fp = builtins.open(filename, "r+b")
#    2349             else:
# -> 2350                 fp = builtins.open(filename, "w+b")
#    2351
#    2352         try:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'static/ooks_read.png'
